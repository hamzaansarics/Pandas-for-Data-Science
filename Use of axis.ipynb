# %%
import pandas as pd

# %%
dataset=pd.read_csv('E:\Datasets\CSV\movie_users.csv')

# %%
dataset.std(axis=1)
dataset.std(axis=0)
dataset.mean(axis=1)
dataset.mean(axis=0)
dataset.max(axis=1)
dataset.max(axis=0)
dataset.min(axis=1)
dataset.min(axis=0)
dataset.sum(axis=1)
dataset.sum(axis=0)
dataset.drop('genre',axis=1)
dataset.drop(2,axis=0)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 3            PG-13     Action       152
# ...

# %%
dataset
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...
