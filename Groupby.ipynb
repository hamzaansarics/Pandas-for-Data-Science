# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_table(r'I:\Text Datasets\CSV\titanic.csv',sep=',')
# Out:
# C:\Users\Programmer\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.

# %%
dataset.groupby('continent').beer_servings.mean()
dataset
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
mx=dataset.beer_servings.max()
fd=0
for index,row in dataset.iterrows():
    if row.beer_servings>=mx:
        fd=index
dataset.iloc[fd]
# Out:
# country                         Namibia
# beer_servings                       376
# spirit_servings                       3
# wine_servings                         1
# total_litres_of_pure_alcohol        6.8
# continent                        Africa
# Years                              1944
# Name: 117, dtype: object

# %%
# dataset[dataset.continent=='Africa']

# %%
dataset.groupby('continent').beer_servings.agg(['min','max','mean','std'])
# Out:
#                min  max        mean        std
# continent
# Africa           0  376   61.471698  80.557816
# Asia             0  247   37.045455  49.469725
# Europe           0  361  193.777778  99.631569
# North America    1  285  145.434783  79.621163
# Oceania          0  306   89.687500  96.641412
# South America   93  333  175.083333  65.242845

# %%
dd=dataset.groupby('continent').mean()

# %%
data=[x*10 for x in range(1,21)]
plt.plot([],[],label='min',color='r')
plt.plot([],[],label='max',color='g')
plt.plot([],[],label='mean',color='orange')
plt.plot([],[],label='std',color='c')
plt.plot(dd)
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.isnull(),yticklabels=False,xticklabels=True)

# %%
sns.scatterplot(dataset.wine_servings,dataset.spirit_servings)

# %%
plt.scatter(dataset.wine_servings,dataset.spirit_servings)
