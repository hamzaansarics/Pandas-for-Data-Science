# %%
import pandas as pd

# %%
df=pd.read_csv(r'I:\Text Datasets\CSV\titanic.csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df['Sex_Encoded']=df.Sex.map({'male':1,'female':0})

# %%
df['SEX']=pd.get_dummies(df.Sex).iloc[:,[1]]

# %%
nn=pd.get_dummies(df.Embarked,prefix='Embarked').iloc[:,1:]

# %%
pd.concat([df,nn],axis=1).head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Sex_Encoded  SEX  Embarked_Q  \
# 0      0  A/5 21171   7.2500   NaN        S            1    1           0
# 1      0   PC 17599  71.2833   C85        C            0    0           0
#
#    Embarked_S
# 0           1
# 1           0

# %%
pd.get_dummies(df,columns=['Sex','Embarked'],drop_first=True).head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
#
#       Ticket     Fare Cabin  Sex_Encoded  SEX  Sex_male  Embarked_Q  \
# 0  A/5 21171   7.2500   NaN            1    1         1           0
# 1   PC 17599  71.2833   C85            0    0         0           0
#
#    Embarked_S
# 0           1
# 1           0
