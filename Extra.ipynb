# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('I:\Text Datasets\CSV\movie_users.csv')
dataset.head()
dataset.title.swaplevel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-b45151ad7fa9> in <module>
#       1 dataset=pd.read_csv('I:\Text Datasets\CSV\movie_users.csv')
#       2 dataset.head()
# ----> 3 dataset.title.swaplevel()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in swaplevel(self, i, j, copy)
#    3233            the two innermost levels of the index.
#    3234         """
# -> 3235         new_index = self.index.swaplevel(i, j)
#    3236         return self._constructor(self._values, index=new_index,
#    3237                                  copy=copy).__finalize__(self)
#
# AttributeError: 'RangeIndex' object has no attribute 'swaplevel'

# %%
for index,row in dataset.iterrows():
    print(index,row.title,row.genre,row.content_rating)

# %%
dataset.select_dtypes([np.object])

# %%
VL=[]
for v in range(len(dataset.dtypes)):
    if dataset.dtypes[v]!='object':
        pass
    else:
        VL.append(v)
print(VL)
dataset1=pd.read_csv('E:\Datasets\CSV\movie_users.csv',usecols=VL)
# Out:
# [1, 2, 3, 5]

# %%
dataset1.describe(include=['object'])
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
dataset.sort_values(['star_rating','genre','duration'],ascending=True).head()
# Out:
#      star_rating                                            title  \
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
# 943          7.4                                  The Bucket List
#
#     content_rating      genre  duration  \
# 954          PG-13     Action       104
# 963              R     Action       118
# 967              R     Action       136
# 976          PG-13     Action       138
# 943          PG-13  Adventure        97
#
#                                            actors_list
# 954  [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...
# 963  [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# 967   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# ...

# %%
dataset.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
import re
dataset[dataset.genre.str.contains('action|crime',regex=True,flags=re.I)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
re.findall(re.compile('Action|Crime'),str(['Crime','Action']))
# Out:
# ['Crime', 'Action']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-750e2e19a932> in <module>
# ----> 1 pd.at()
#
# NameError: name 'pd' is not defined
