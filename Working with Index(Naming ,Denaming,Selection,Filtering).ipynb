# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_table('I://Text Datasets//CSV//chipotle.csv')

# %%
dataset.index.name=None

# %%
dataset.index.name='nice'
dataset.set_index('item_name',inplace=True)

# %%
type(dataset.loc[23,'item_name']
# Out:
#   File "<ipython-input-26-e6f5a61f5739>", line 1
#     type(dataset.loc[23,'item_name']
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
dataset.describe().loc['std','order_id']
# Out:
# 528.8907955866094

# %%
dataset.loc['Izze','order_id']
# Out:
# item_name
# Izze       1
# Izze      12
# Izze      21
# Izze      30
# Izze     155
# Izze     155
# Izze     186
# Izze     237
# Izze     237
# Izze     436
# Izze     495
# Izze     651
# Izze     651
# Izze     680
# Izze     842
# Izze    1040
# Izze    1046
# Izze    1095
# Izze    1149
# Izze    1468
# Name: order_id, dtype: int64

# %%
dataset.reset_index()
# Out:
#                                   item_name  order_id  quantity  \
# 0              Chips and Fresh Tomato Salsa         1         1
# 1                                      Izze         1         1
# 2                          Nantucket Nectar         1         1
# 3     Chips and Tomatillo-Green Chili Salsa         1         1
# 4                              Chicken Bowl         2         2
# ...                                     ...       ...       ...
# 4617                          Steak Burrito      1833         1
# 4618                          Steak Burrito      1833         1
# 4619                     Chicken Salad Bowl      1834         1
# 4620                     Chicken Salad Bowl      1834         1
# 4621                     Chicken Salad Bowl      1834         1
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
pd.set_option('display.max_colwidth',100)

# %%
dataset
# Out:
#                                        order_id  quantity  \
# item_name
# Chips and Fresh Tomato Salsa                  1         1
# Izze                                          1         1
# Nantucket Nectar                              1         1
# Chips and Tomatillo-Green Chili Salsa         1         1
# Chicken Bowl                                  2         2
# ...                                         ...       ...
# Steak Burrito                              1833         1
# Steak Burrito                              1833         1
# Chicken Salad Bowl                         1834         1
# Chicken Salad Bowl                         1834         1
# Chicken Salad Bowl                         1834         1
#
#                                                                                                       choice_description  \
# item_name
# Chips and Fresh Tomato Salsa                                                                                         NaN
# ...
